# %%
import pandas as pd

# %%
df = pd.read_html('./data/2001Y_10M.xls',encoding='utf-8')
df[0]
# Out:
#           0              1           2            3          4           5  \
# 0      類型代號           基金統編        基金名稱         基金規模       單位淨值  本月定時定額扣款筆數
# 1         2       00965469      國際第一基金     50642376     5.8200           0
# 2         5       00971976      國際萬全基金    720584635     8.9400        2687
# 3         4       00992769      國際全球基金   2209482939    25.4000       10595
# 4         6       01013101      國際萬寶基金  41146353434    13.7689           0
# 5         2       01050148      國際國民基金    382415320    13.8800          18
# 6         2       17606299      國際金龍基金    594864448     3.3700         234
# 7         7       20095341      國際萬通基金   1809133766    12.8255         171
# 8         3       21100568      國際台灣基金   4587221629    87.2500           0
# 9         2       73991751      國際電子基金   1042194234     8.7400        2295
# 10        2       81584996      國際店頭基金    812968192     7.5700        1446
# ...

# %%
# bb = pd.ExcelWriter('out.xlsx')
# df[0].to_excel(bb)
# bb.close()
